# %%
# !pip install faker
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Collecting faker
#   Downloading faker-40.1.2-py3-none-any.whl (2.0 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.0/2.0 MB 5.0 MB/s eta 0:00:0000:0100:01
# Installing collected packages: faker
#   WARNING: The script faker is installed in '/home/hadoop/.local/bin' which is not on PATH.
#   Consider adding this directory to PATH or, if you prefer to suppress this warning, use --no-warn-script-location.
# Successfully installed faker-40.1.2
#
# [notice] A new release of pip is available: 23.0.1 -> 25.3
# [notice] To update, run: python3.11 -m pip install --upgrade pip

# %%
from dateutil.relativedelta import *
import json 
import boto3 as b 
import base64
from faker import Faker
import time 
fake = Faker()
stream_name = 'kinesis-event-stream'
kinesis_client = b.client('kinesis')

# %%
london_boroughs = [
    'Barking and Dagenham','Barnet','Bexley','Brent','Bromley','Camden','Croydon','Ealing','Enfield','Greenwich','Hackney','Hammersmith and Fulham','Haringey','Harrow','Havering','Hillingdon','Hounslow','Islington','Kensington and Chelsea','Kingston upon Thames','Lambeth','Lewisham','Merton','Newham','Redbridge','Richmond upon Thames','Southwark','Sutton','Tower Hamlets','Waltham Forest','Wandsworth','Westminster','City of London'
]

# %%
# True case 
input_jsons = []
for batch_round in range(1,fake.random_int(min=9,max=10)):
    print(f'Batch Count {batch_round}\n')
    upload_count = 0
    for _ in range(0,fake.random_int(min=1,max=10)): 
        input_json = {}
        # Patienets Data
        input_json['partition_key'] = (fake.uuid4())
        input_json['patient_id'] = (fake.random_int(min=1000,max=9999))
        input_json['name_prefix'] = (fake.prefix())
        input_json['first_name'] = (fake.first_name())
        input_json['last_name'] = (fake.last_name())
        input_json['date_of_birth'] = (fake.date_of_birth(minimum_age=18, maximum_age=65)).strftime('%d-%m-%Y')
        input_json['phone_number'] = (fake.msisdn())
        input_json['email_id'] = (fake.email())
        # Policy Data 
        input_json['policy_id' ] = (fake.random_int(min=1000,max=9999))
        input_json['policy_start_date'] = fake.date_between('-20y','+5y').strftime('%d/%m/%Y')
        input_json['policy_end_date'] = '2031/01/01'
        input_json['preimum_amount'] = ('$'+fake.numerify('$00'))
        input_json['coverage_limit'] = ('$'+fake.numerify('$$000'))
        # Address Data 
        input_json['addres_id'] = (fake.random_int(min=1000,max=9999))
        input_json['addressline'] = f"{fake.building_number()} {fake.street_name()}"
        input_json['city'] = "London"
        input_json['state'] = "England" 
        input_json['borough'] = fake.random_choices(london_boroughs, length = 1 )[0]
        # Claim Data 
        input_json['claim_id'] = (fake.random_int(min=1000,max=9999))
        input_json['claim_initialized_date'] = fake.date_between('-20y','+5y').strftime('%d/%m/%Y')
        input_json['claim_request_amount'] = '$'+ str(fake.random_int(min=1000,max=99999))
        input_json['claim_status'] = fake.random_choices(['Accepted','Rejected','Under Process' ,'Initalized','Settled','Received'], length=1)[0]
        if ('Rejected') in  input_json['claim_status'] :
            input_json['claim_rejected_reason'] = fake.random_choices(['Policy Expired','Policy Not Created',''], length=1)[0]
        else:
            input_json['claim_rejected_reason'] = fake.random_choices([''], length=1)[0]
        
        json_dataset = json.dumps(input_json)
        response = kinesis_client.put_record(StreamName=stream_name, Data=json_dataset, PartitionKey = input_json['partition_key'] )
        upload_count = upload_count + 1
        print(f"Uploaded Customer ID `{input_json['patient_id']}` to Shard ID `{response['ShardId']}` with Sequence Number `{response['SequenceNumber']}`")
    print(f'\nUploaded {upload_count} customer details to the stream')
    print('Sleep - 5 Seconds\n')
    time.sleep(5)
# Out:
# Batch Count 1
#
# Uploaded Customer ID `1929` to Shard ID `shardId-000000000000` with Sequence Number `49671310290086716660127903442743728352200823067893563394`
# Uploaded Customer ID `2534` to Shard ID `shardId-000000000000` with Sequence Number `49671310290086716660127903442972215332107988050632507394`
# Uploaded Customer ID `5842` to Shard ID `shardId-000000000000` with Sequence Number `49671310290086716660127903443223671902587830918971392002`
# Uploaded Customer ID `8219` to Shard ID `shardId-000000000000` with Sequence Number `49671310290086716660127903443518649802573800437599698946`
# Uploaded Customer ID `3977` to Shard ID `shardId-000000000000` with Sequence Number `49671310290086716660127903443724167191908287397299748866`
# Uploaded Customer ID `2155` to Shard ID `shardId-000000000000` with Sequence Number `49671310290086716660127903443930893507062388986174504962`
# Uploaded Customer ID `7214` to Shard ID `shardId-000000000000` with Sequence Number `49671310290086716660127903444132784118938032058350436354`
# Uploaded Customer ID `4228` to Shard ID `shardId-000000000000` with Sequence Number `49671310290086716660127903444447104832037835781212995586`
# Uploaded Customer ID `1146` to Shard ID `shardId-000000000000` with Sequence Number `49671310290086716660127903444771096951694556400034250754`
# Uploaded Customer ID `7115` to Shard ID `shardId-000000000000` with Sequence Number `49671310290086716660127903445014091041437096864150192130`
#
# Uploaded 10 customer details to the stream
# Sleep - 5 Seconds
#
# Batch Count 2
#
# Uploaded Customer ID `6460` to Shard ID `shardId-000000000000` with Sequence Number `49671310290086716660127903450237859507991909871652962306`
# Uploaded Customer ID `3236` to Shard ID `shardId-000000000000` with Sequence Number `49671310290086716660127903450495360707569825885865377794`
#
# Uploaded 2 customer details to the stream
# Sleep - 5 Seconds
#
# Batch Count 3
#
# Uploaded Customer ID `2932` to Shard ID `shardId-000000000000` with Sequence Number `49671310290086716660127903456096314029844403195876474882`
# Uploaded Customer ID `4217` to Shard ID `shardId-000000000000` with Sequence Number `49671310290086716660127903456296995715900431707597176834`
# Uploaded Customer ID `7578` to Shard ID `shardId-000000000000` with Sequence Number `49671310290086716660127903456543616583101816059237236738`
# Uploaded Customer ID `5053` to Shard ID `shardId-000000000000` with Sequence Number `49671310290086716660127903456778148192107054119130234882`
# Uploaded Customer ID `2177` to Shard ID `shardId-000000000000` with Sequence Number `49671310290086716660127903457009053023653448291499114498`
# Uploaded Customer ID `6352` to Shard ID `shardId-000000000000` with Sequence Number `49671310290086716660127903457214570412987935251199164418`
#
# Uploaded 6 customer details to the stream
# Sleep - 5 Seconds
#
# Batch Count 4
#
# Uploaded Customer ID `1948` to Shard ID `shardId-000000000000` with Sequence Number `49671310290086716660127903462411742511511226485577875458`
#
# Uploaded 1 customer details to the stream
# Sleep - 5 Seconds
#
# Batch Count 5
#
# Uploaded Customer ID `3374` to Shard ID `shardId-000000000000` with Sequence Number `49671310290086716660127903468096111715339213208643698690`
# Uploaded Customer ID `7052` to Shard ID `shardId-000000000000` with Sequence Number `49671310290086716660127903468353612914917129222856114178`
#
# Uploaded 2 customer details to the stream
# Sleep - 5 Seconds
#
# Batch Count 6
#
# Uploaded Customer ID `8665` to Shard ID `shardId-000000000000` with Sequence Number `49671310290086716660127903473663215114664580970482499586`
# Uploaded Customer ID `6772` to Shard ID `shardId-000000000000` with Sequence Number `49671310290086716660127903473889284242932516626152554498`
#
# Uploaded 2 customer details to the stream
# Sleep - 5 Seconds
#
# Batch Count 7
#
# Uploaded Customer ID `5214` to Shard ID `shardId-000000000000` with Sequence Number `49671310290086716660127903478915997800890145078178217986`
# Uploaded Customer ID `1540` to Shard ID `shardId-000000000000` with Sequence Number `49671310290086716660127903479144484780797309992197685250`
# Uploaded Customer ID `3929` to Shard ID `shardId-000000000000` with Sequence Number `49671310290086716660127903479366927131606401829063098370`
# Uploaded Customer ID `1243` to Shard ID `shardId-000000000000` with Sequence Number `49671310290086716660127903479560355262744742497016086530`
# Uploaded Customer ID `1538` to Shard ID `shardId-000000000000` with Sequence Number `49671310290086716660127903479835990349616877948849094658`
# Uploaded Customer ID `4122` to Shard ID `shardId-000000000000` with Sequence Number `49671310290086716660127903480078984439359418412965036034`
# Uploaded Customer ID `3737` to Shard ID `shardId-000000000000` with Sequence Number `49671310290086716660127903480325605306560802833324572674`
#
# Uploaded 7 customer details to the stream
# Sleep - 5 Seconds
#
# Batch Count 8
#
# Uploaded Customer ID `7696` to Shard ID `shardId-000000000000` with Sequence Number `49671310290086716660127903485299126128455387601663164418`
# Uploaded Customer ID `4664` to Shard ID `shardId-000000000000` with Sequence Number `49671310290086716660127903485549373773115615840827342850`
# Uploaded Customer ID `3504` to Shard ID `shardId-000000000000` with Sequence Number `49671310290086716660127903485789950011218927046593871874`
# Uploaded Customer ID `4907` to Shard ID `shardId-000000000000` with Sequence Number `49671310290086716660127903486017228065306477331438632962`
#
# Uploaded 4 customer details to the stream
# Sleep - 5 Seconds
#
# Batch Count 9
#
# Uploaded Customer ID `8583` to Shard ID `shardId-000000000000` with Sequence Number `49671310290086716660127903491586749316271074351626846210`
# Uploaded Customer ID `8355` to Shard ID `shardId-000000000000` with Sequence Number `49671310290086716660127903491844250515848990365839261698`
# Uploaded Customer ID `8370` to Shard ID `shardId-000000000000` with Sequence Number `49671310290086716660127903492129557009278042851069919234`
# Uploaded Customer ID `9691` to Shard ID `shardId-000000000000` with Sequence Number `49671310290086716660127903492424534909264012369698226178`
# Uploaded Customer ID `1949` to Shard ID `shardId-000000000000` with Sequence Number `49671310290086716660127903492764243064575723236510138370`
# Uploaded Customer ID `8159` to Shard ID `shardId-000000000000` with Sequence Number `49671310290086716660127903493142636846115102168193171458`
# Uploaded Customer ID `6369` to Shard ID `shardId-000000000000` with Sequence Number `49671310290086716660127903493580267992815597929436807170`
#
# Uploaded 7 customer details to the stream
# Sleep - 5 Seconds
